# %%
pip install tableone
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tableone
#   Downloading tableone-0.9.1-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 2.5 MB/s eta 0:00:00
# Collecting numpy>=1.19.1
#   Downloading numpy-2.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 4.7 MB/s eta 0:00:00:00:0100:01
# Collecting pandas>=2.0.3
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 50.4 MB/s eta 0:00:0000:0100:01
# Collecting openpyxl>=3.1.2
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 13.4 MB/s eta 0:00:00
# Collecting scipy>=1.10.1
#   Downloading scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 22.0 MB/s eta 0:00:0000:0100:01
# Collecting tabulate>=0.9.0
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting jinja2>=3.1.4
#   Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 9.7 MB/s eta 0:00:00
# Collecting statsmodels>=0.14.1
#   Downloading statsmodels-0.14.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 50.5 MB/s eta 0:00:0000:0100:01
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Collecting pytz>=2020.1
#   Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 14.4 MB/s eta 0:00:0000:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.10/site-packages (from pandas>=2.0.3->tableone) (2.9.0.post0)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.3 in /home/vscode/.local/lib/python3.10/site-packages (from statsmodels>=0.14.1->tableone) (24.1)
# Collecting patsy>=0.5.6
#   Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: six in /home/vscode/.local/lib/python3.10/site-packages (from patsy>=0.5.6->statsmodels>=0.14.1->tableone) (1.16.0)
# Installing collected packages: pytz, tzdata, tabulate, numpy, MarkupSafe, et-xmlfile, scipy, patsy, pandas, openpyxl, jinja2, statsmodels, tableone
# Successfully installed MarkupSafe-3.0.2 et-xmlfile-2.0.0 jinja2-3.1.4 numpy-2.1.2 openpyxl-3.1.5 pandas-2.2.3 patsy-0.5.6 pytz-2024.2 scipy-1.14.1 statsmodels-0.14.4 tableone-0.9.1 tabulate-0.9.0 tzdata-2024.2
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.12.4-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 6.7 MB/s eta 0:00:0000:01
# Collecting scikit-learn>=1.0.2
#   Downloading scikit_learn-1.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 39.1 MB/s eta 0:00:0000:0100:01
# Collecting joblib>=1.1.1
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 10.9 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: scipy>=1.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.14.1)
# Requirement already satisfied: numpy>=1.17.3 in /home/vscode/.local/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (2.1.2)
# Installing collected packages: threadpoolctl, joblib, scikit-learn, imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.12.4 imblearn-0.0 joblib-1.4.2 scikit-learn-1.5.2 threadpoolctl-3.5.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
from tableone import TableOne, load_dataset
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from imblearn.under_sampling import RandomUnderSampler

# %%
def is_binary(df_, nums):
    df = df_.copy()
    variables = []
    for var in nums:
        flag = True
        unique = df_[var].unique()
        for value in unique:
            if value not in [0, 1, np.nan, 0.0, 1.0]:
                flag = False
        if flag == True:
            variables.append(var)
    return variables

def breakdown_vars(df, off_binary=False):
    """
    This function allow us categorize accodign to numerical or not
    """
    binaries = is_binary(df, df.columns)
    categorial = []
    nonormal = []
    normal = []
    for t in df.columns:
        if off_binary == False:
          if (df[t].dtypes.name=="object" or df[t].dtypes.name=='category') and  t not in binaries:
            categorial.append(t)
        else:
           if (df[t].dtypes.name=="object" or df[t].dtypes.name=='category'):
            categorial.append(t)
        if (df[t].dtypes=="int64" or df[t].dtypes=="float64") and t not in binaries:
                n,p = stats.shapiro(df[t])
                if p<0.05:
                    nonormal.append(t)
                else:
                    normal.append(t)
    if off_binary == False:
      return categorial, binaries, nonormal, normal
    else:
      return categorial, nonormal, normal

# %%
url='https://raw.githubusercontent.com/4GeeksAcademy/decision-tree-project-tutorial/main/diabetes.csv'

# %%
df=pd.read_csv(url)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
X= df.drop(columns='Outcome').copy()
y= df['Outcome']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, shuffle=True, random_state=12,stratify=y)

# %%
arbol=DecisionTreeClassifier(random_state=12)
preds=arbol.fit(X_train,y_train).predict(X_test)
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80       100
#            1       0.62      0.65      0.64        54
#
#     accuracy                           0.74       154
#    macro avg       0.72      0.72      0.72       154
# weighted avg       0.74      0.74      0.74       154

# %%
def grid_RandomForest(X_train, y_train):
  model = RandomForestClassifier(random_state=0)
  n_estimators = [100,500,1000]
  criterion = ['gini', 'entropy', 'log_loss']
  min_samples_split = [0.05, 0.1,]
  max_depth = [2,3,4]
  grid = dict(n_estimators = n_estimators, criterion = criterion,
              min_samples_split = min_samples_split, max_depth = max_depth)
  cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=1, random_state=1)
  grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv,
                            scoring='f1',error_score='raise')
  grid_result = grid_search.fit(X_train, y_train)
  return  grid_result.best_estimator_

# %%
rus = RandomUnderSampler(random_state=542)
X_train, y_train = rus.fit_resample(X_train, y_train)

# %%
best_rfc=grid_RandomForest(X_train,y_train)
preds3=best_rfc.predict(X_test)
print(classification_report(y_test,preds3))
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/numpy/ma/core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84       100
#            1       0.69      0.80      0.74        54
#
#     accuracy                           0.81       154
#    macro avg       0.79      0.80      0.79       154
# weighted avg       0.81      0.81      0.81       154

# %%
from pickle import dump

dump(best_rfc, open("modelRFFlask.sav", "wb"))
